# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
import airbndacquire as a

# %% [markdown]
# # Goal:
# Understand the trend and seasonality in the Airbnb booking data in NYC.

# %% [markdown]
# # Data Preprocessing:
#
# Handle Missing Values
#
# Convert the date column to a datetime data type
#
# Extract year, month, and day for further analysis

# %% [markdown]
# # Time Series Decomposition
#
# Observe the trend, seasonal, and residual components of the time series data
#
# # Time Series Forecasting
#
# Develop a model to predict future booking trends

# %%
df = pd.read_csv('airbnb_nyc.csv')
df.head(3)
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park     2787       John
# 1  2595                Skylit Midtown Castle     2845   Jennifer
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# ...

# %%
time_series_data, (stats, preview) = a.plot_timeseries_data(data_clean, 'last_review')

# %% [markdown]
# The time series plot illustrates the number of Airbnb reviews in NYC from March 28, 2011, to July 8, 2019. we can observe upward trend

# %%
decomposition = a.decompose_and_plot_timeseries(time_series_data, 'last_review', 'number_of_reviews')

# %% [markdown]
# Original: Shows the original time series data, representing the number of reviews over time.
#
#
# Trend: Represents the overall trend in the data. There’s a clear upward trend, indicating a general increase in Airbnb reviews over time in NYC.
#
# Seasonal: Represents the seasonal component, which repeats over a specific period. There’s a clear yearly seasonality, with peaks (likely during tourist seasons) and troughs.
#
# Residual: Represents the residuals or the noise after extracting the trend and seasonal components. We will further investigate this to understand any anomalies or patterns not captured by the trend and seasonality.

# %% [markdown]
# # # Question 1: Is there a noticeable upward trend in the number of bookings over the years?

# %% [markdown]
# Hypothesis H0: There is a significant upward trend in the number of bookings over the years.
#
#
# Hypothesis Ha: There is not a significant upward trend in the number of booking over the years.

# %%
annual_reviews = a.plot_annual_reviews_and_growth(data_clean, 'last_review')

# %% [markdown]
# We reject alternative hypothesis :
#
# The plot showcases both the annual number of reviews and a proxy for bookings, and the annual growth rate.

# %% [markdown]
# # Question 2: Is there a seasonal pattern in bookings, especially a peak in certain months?
#
# Hypothesis Ho: Bookings exhibit a seasonal pattern, peaking during particular months.
#
# Hypthesis Ha: Bookings  does not exhibit a seasonal pattern.

# %%
monthly_reviews_general = a.plot_general_monthly_reviews(data_clean, 'last_review')

# %% [markdown]
# The peak in June might be attributed to factors like summer vacations, festivals, or other events, warranting further investigation.

# %% [markdown]
# # conclusion:
# availablity might be tight during summer season plan ahaead or cancel the trip

# %% [markdown]
# # Next steps:
#
# Complete the project that folllows pipeline demo.
#
#
# Modeling, testing..
